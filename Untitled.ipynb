# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import os
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from tqdm import tqdm
# %matplotlib inline
sns.set()
pd.set_option('max_columns', 105)

# %%
DATA_ROOT = './COVID-19'
archived_data = os.path.join(DATA_ROOT, 'archived_data')
csse_data = os.path.join(DATA_ROOT, 'csse_covid_19_data')
who_reports = os.path.join(DATA_ROOT, 'who_covid_19_situation_reports')

# %%
csse_confirmed_path = os.path.join(csse_data,'csse_covid_19_time_series',  'time_series_covid19_confirmed_global.csv')
csse_deaths_path = os.path.join(csse_data,'csse_covid_19_time_series', 'time_series_covid19_deaths_global.csv')
csse_recovered_path = os.path.join(csse_data,'csse_covid_19_time_series', 'time_series_covid19_recovered_global.csv')

# %%
csse_confirmed_df = pd.read_csv(csse_confirmed_path)

hubei = csse_confirmed_df[(csse_confirmed_df['Country/Region'] == 'China' ) & (csse_confirmed_df['Province/State'] == 'Hubei' )]
hubei['Country/Region'] = 'China - Hubei'
csse_confirmed_df = pd.concat([csse_confirmed_df, hubei])

csse_deaths_df = pd.read_csv(csse_deaths_path)

hubei = csse_deaths_df[(csse_deaths_df['Country/Region'] == 'China' ) & (csse_deaths_df['Province/State'] == 'Hubei' )]
hubei['Country/Region'] = 'China - Hubei'
csse_deaths_df = pd.concat([csse_deaths_df, hubei])

csse_recovered_df = pd.read_csv(csse_recovered_path)

hubei = csse_recovered_df[(csse_recovered_df['Country/Region'] == 'China' ) & (csse_recovered_df['Province/State'] == 'Hubei' )]
hubei['Country/Region'] = 'China - Hubei'
csse_recovered_df = pd.concat([csse_recovered_df, hubei])

csse = {'confirmed':csse_confirmed_df,'deaths':csse_deaths_df,'recovered':csse_recovered_df}
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
def transpose_df(df):
    cols = [x for x in df.columns if x not in ['Country/Region','Province/State','Lat', 'Long']]
    df = df.groupby(['Country/Region'])[cols].agg('sum').reset_index().set_index('Country/Region').T
    df.columns.names = ['']
    df.reset_index(inplace=True)
    df.rename(columns={'index':'Date'}, inplace=True)
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    return df

# %%
for key, value in csse.items():
    csse[key] = transpose_df(value)
    #csse[key] = csse[key].iloc[0:len(csse[key])-1]

# %%
territories = set(list(csse['confirmed'].columns) + list(csse['deaths'].columns) + list(csse['recovered'].columns))

# %%
#pd.DataFrame({'Territory':territories, 'Population':[0]*len(list(territories))}).to_csv('population.csv', index=False)
population_df = pd.read_csv('population_1.csv')

# %%
set(csse['recovered'].columns) - set(csse['confirmed'].columns)
# Out:
# set()

# %%
from datetime import timedelta
for key, value in csse.items():
    print(key)
    print(value.shape)
    missing_countries = set(territories) - set(value.columns)
    print(missing_countries)
    for country in missing_countries:
        value[country] = np.nan
    value.fillna(0, inplace=True)
    print(value.shape)
    while csse[key].shape[0] < csse['confirmed'].shape[0]:
        new_row = value.iloc[len(value)-1:len(value)]
        new_row.index += timedelta(days=1)
        display(new_row)
        csse[key] = pd.concat([value, new_row])
    print(value.shape)
# Out:
# confirmed
# (90, 186)
# set()
# (90, 186)
# (90, 186)
# deaths
# (90, 186)
# set()
# (90, 186)
# (90, 186)
# recovered
# (90, 186)
# set()
# (90, 186)
# (90, 186)

# %%
csse['absolute'] = csse['confirmed'].copy()
c = [x for x in csse['absolute'].columns if x not in ['Date']]
csse['absolute'][c] = (csse['confirmed'][c] - csse['recovered'][c]) - csse['deaths'][c]

# %%
csse['recovered']
# Out:
#             Afghanistan  Albania  Algeria  Andorra  Angola  \
# Date
# 2020-01-
uzbekistan  Venezuela  Vietnam  West Bank and Gaza  \
# Date
# 2020-01-22           0          0        0                   0
# 2020-01-23           0          0        0                   0
# 2020-01-24           0          0        0                   0
# 2020-01-25           0          0        0                   0
# 2020-01-26           0          0        0                   0
# ...                ...        ...      ...                 ...
# 2020-04-16         129        111      177                  63
# 2020-04-17         156        111      198                  69
# 2020-04-18         194        113      201                  69
# 2020-04-19         225        117      202                  71
# 2020-04-20         261        117      214                  71
#
#             Western Sahara  Yemen  Zambia  Zimbabwe
# Date
# 2020-01-22               0      0       0         0
# 2020-01-23               0      0       0         0
# 2020-01-24               0      0       0         0
# 2020-01-25               0      0       0         0
# 2020-01-26               0      0       0         0
# ...                    ...    ...     ...       ...
# 2020-04-16               0      0      30         1
# 2020-04-17               0      0      30         2
# 2020-04-18               0      0      33         2
# 2020-04-19               0      0      33         2
# 2020-04-20               0      0      35         2
#
# [90 rows x 186 columns]

# %%
def delta(row, df, country, firstday = 0, days = 1):
    if row.dayofyear - days <= firstday:
        return 0
    else:
        return int(row[country] - df[df.dayofyear == (row.dayofyear - days)][country])

# %%
checkpoint = 100

# %%
def dayplus(row, df, country):
    first_day = df[df[country] > checkpoint].dayofyear.min()
    if np.isnan(first_day) or row.dayofyear <= first_day:
        return 0
    else:
        return row.dayofyear - first_day

# %%
def create_features(df):
    countries = [x for x in df.columns if x not in ['Date']]
    not_china_cols = [x for x in countries if x not in ['China']]
    df['non-China'] = df[not_china_cols].sum(axis=1)
    not_china_italy_cols = [x for x in countries if x not in ['China', 'Italy']]
    df['non-China-Italy'] = df[not_china_italy_cols].sum(axis=1)
    df['world'] = df[countries].sum(axis=1)
    df['dayofyear'] = df.apply(lambda x : x.name.dayofyear, axis = 1)
    for country in tqdm(countries + ['non-China', 'world', 'non-China-Italy']):
        df[str(country) + '_daily'] = df.apply(lambda x : delta(x, df, country, firstday = df.dayofyear.min()), axis = 1)
        df[str(country) + '_daysplus'] = df.apply(lambda x : dayplus(x, df, country), axis = 1)
    return df

# %%
for key, value in csse.items():
    csse[key] = create_features(value)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:21<00:00,  8.74it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:20<00:00,  9.07it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:21<00:00,  8.90it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:21<00:00,  8.76it/s]

# %% [markdown]
# ## Moving average

# %%
csse['ma'] = csse['absolute'].copy()

# %%
window = 2
for ix, (time, row) in tqdm(enumerate(csse['ma'].iterrows())):
    for key in row.keys():
        if not key.endswith('_daysplus') and key not in ['Date', 'dayofyear']:
            if ix < window - 1:
                csse['ma'][key].iloc[ix] = (csse['absolute'][key].iloc[0:ix+1].sum())/(ix+1)
                #print(0, ix, ix +1, (csse['ma'][key].iloc[0:ix+1].sum())/(ix+1))
            else:
                csse['ma'][key].iloc[ix] = (csse['absolute'][key].iloc[ix-window + 1 :ix+1].sum())/(window)
                #print('a',ix-window + 1,  ix, window, (csse['ma'][key].iloc[ix-window + 1 :ix+1].sum())/(window))
# Out:
# 0it [00:00, ?it/s]c:\program files\python36\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#
# Date
# 2020-01-22                   0.0                        0            0.0
# 2020-01-23                   0.0                        0            0.0
# 2020-01-24                   0.0                        0            0.0
# 2020-01-25                   0.0                        0            0.0
# 2020-01-26                   0.0                        0            0.0
#
#             Uruguay_daysplus  Uzbekistan_daily  Uzbekistan_daysplus  \
# Date
# 2020-01-22                 0               0.0                    0
# 2020-01-23                 0               0.0                    0
# 2020-01-24                 0               0.0                    0
# 2020-01-25                 0               0.0                    0
# 2020-01-26                 0               0.0                    0
#
#             Venezuela_daily  Venezuela_daysplus  Vietnam_daily  \
# Date
# 2020-01-22              0.0                   0            0.0
# 2020-01-23              0.0                   0            0.0
# 2020-01-24              0.0                   0            0.0
# 2020-01-25              0.0                   0            0.0
# 2020-01-26              0.0                   0            0.0
#
#             Vietnam_daysplus  West Bank and Gaza_daily  \
# Date
# 2020-01-22                 0                       0.0
# 2020-01-23                 0                       0.0
# 2020-01-24                 0                       0.0
# 2020-01-25                 0                       0.0
# 2020-01-26                 0                       0.0
#
#             West Bank and Gaza_daysplus  Western Sahara_daily  \
# Date
# 2020-01-22                            0                   0.0
# 2020-01-23                            0                   0.0
# 2020-01-24                            0                   0.0
# 2020-01-25                            0                   0.0
# 2020-01-26                            0                   0.0
#
#             Western Sahara_daysplus  Yemen_daily  Yemen_daysplus  \
# Date
# 2020-01-22                        0          0.0               0
# 2020-01-23                        0          0.0               0
# 2020-01-24                        0          0.0               0
# 2020-01-25                        0          0.0               0
# 2020-01-26                        0          0.0               0
#
#             Zambia_daily  Zambia_daysplus  Zimbabwe_daily  Zimbabwe_daysplus  \
# Date
# 2020-01-22           0.0                0             0.0                  0
# 2020-01-23           0.0                0             0.0                  0
# 2020-01-24           0.0                0             0.0                  0
# 2020-01-25           0.0                0             0.0                  0
# 2020-01-26           0.0                0             0.0                  0
#
#             non-China_daily  non-China_daysplus  world_daily  world_daysplus  \
# Date
# 2020-01-22              0.0                   0          0.0               0
# 2020-01-23              0.0                   1          0.0               1
# 2020-01-24             52.5                   2        184.0               2
# 2020-01-25            153.5                   3        518.5               3
# 2020-01-26            244.5                   4        800.5               4
#
#             non-China-Italy_daily  non-China-Italy_daysplus
# Date
# 2020-01-22                    0.0                         0
# 2020-01-23                    0.0                         1
# 2020-01-24                   52.5                         2
# 2020-01-25                  153.5                         3
# 2020-01-26                  244.5                         4
#
# [5 rows x 568 columns]

# %%
plt.figure(figsize=(16, 10))
ax = sns.lineplot(data=csse['confirmed'][['world']], markers=True, dashes=False, palette=['red'], label='confirmed')
#ax.set(yscale="log")
ax = sns.lineplot(data=csse['recovered'][['world']], markers=False, dashes=True, palette=['green'], label='recovered')
#ax.set(yscale="log")
ax = sns.lineplot(data=csse['ma'][['world']], markers=True, dashes=True, label='ma')
#ax.set(yscale="log")

# %%
plt.figure(figsize=(15, 10))
sns.set_context("talk")
#sns.lineplot(data=csse['confirmed'][['non-China-Italy_daily']], markers=True, dashes=False)
#sns.lineplot(data=csse['recovered'][['non-China-Italy_daily']], markers=False, dashes=True)
#top_10 = list(csse['confirmed'][territories].iloc[len(csse['confirmed'])-1].sort_values(ascending=False).head(10).index)
top_10 = ['Argentina', 'Italy',  'Spain', 'Brazil', 'US']#, 'Iran', 'Korea, South', 'United Kingdom']#'US',
for c in top_10:
    ax = sns.lineplot(x=csse['absolute'][csse['confirmed'][c]>checkpoint][c+'_daysplus'], 
                 y=csse['absolute'][csse['confirmed'][c]>checkpoint][c], markers=True, dashes=True, label=c)
ax.set(xlabel='Days since 548th infected', ylabel='Deaths', title='Top 10 infected territories')
ax.set(yscale="log")

plt.show()
plt.figure(figsize=(15, 10))
for c in top_10:
    ax = sns.lineplot(x=csse['absolute'][(csse['absolute'][c]>checkpoint) & (csse['confirmed'][c+'_daysplus']<20)][c+'_daysplus'], 
                 y=csse['absolute'][(csse['absolute'][c]>checkpoint) & (csse['confirmed'][c+'_daysplus']<20)][c], markers=True, dashes=True, label=c)
ax.set(xlabel='Days since 548th infected', ylabel='Deaths', title='Top 10 infected territories')
ax.set(yscale="log")
# Out:
# [None]

# %% [markdown]
# ### As population %

# %%
population_df = pd.read_csv('population_1.csv')
pop = population_df[population_df.Territory.isin([x for x in territories if x not in ['China']])].sum().Population
countr = 'non-China'
non_China = pd.DataFrame({'Territory':[countr], 'Population':[pop]})
population_df = pd.concat([population_df,non_China])

pop = population_df[population_df.Territory.isin([x for x in territories if x not in ['China', 'Italy']])].sum().Population
countr = 'non-China-Italy'
non_China_It = pd.DataFrame({'Territory':[countr], 'Population':[pop]})
population_df = pd.concat([population_df,non_China_It])

pop = population_df[population_df.Territory.isin([x for x in territories])].sum().Population
countr = 'world'
world = pd.DataFrame({'Territory':[countr], 'Population':[pop]})
population_df = pd.concat([population_df,world])

missing = [x for x in territories if x not in population_df.Territory.unique()]
for x in missing.copy():
    missing.append(x +'_daily')
print(missing)
# Out:
# ['Libya', 'Papua New Guinea', 'Western Sahara', 'Guinea-Bissau', 'Sierra Leone', 'Diamond Princess', 'Zimbabwe', 'Cabo Verde', 'Chad', 'Haiti', 'Gambia', 'Uganda', 'Niger', 'Mali', 'MS Zaandam', 'Belize', 'Zambia', 'Burma', 'El Salvador', 'Malawi', 'Timor-Leste', 'West Bank and Gaza', 'Mozambique', 'Syria', 'Kyrgyzstan', 'Saint Kitts and Nevis', 'Fiji', 'Angola', 'Botswana', 'Eritrea', 'Grenada', 'Nicaragua', 'Yemen', 'Dominica', 'Bahamas', 'Djibouti', 'Burundi', 'Mauritius', 'Sao Tome and Principe', 'Laos', 'Madagascar', 'South Sudan', 'Libya_daily', 'Papua New Guinea_daily', 'Western Sahara_daily', 'Guinea-Bissau_daily', 'Sierra Leone_daily', 'Diamond Princess_daily', 'Zimbabwe_daily', 'Cabo Verde_daily', 'Chad_daily', 'Haiti_daily', 'Gambia_daily', 'Uganda_daily', 'Niger_daily', 'Mali_daily', 'MS Zaandam_daily', 'Belize_daily', 'Zambia_daily', 'Burma_daily', 'El Salvador_daily', 'Malawi_daily', 'Timor-Leste_daily', 'West Bank and Gaza_daily', 'Mozambique_daily', 'Syria_daily', 'Kyrgyzstan_daily', 'Saint Kitts and Nevis_daily', 'Fiji_daily', 'Angola_daily', 'Botswana_daily', 'Eritrea_daily', 'Grenada_daily', 'Nicaragua_daily', 'Yemen_daily', 'Dominica_daily', 'Bahamas_daily', 'Djibouti_daily', 'Burundi_daily', 'Mauritius_daily', 'Sao Tome and Principe_daily', 'Laos_daily', 'Madagascar_daily', 'South Sudan_daily']

# %%
#population_df = pd.read_csv('population_1.csv')
missing
# Out:
# ['Libya',
#  'Papua New Guinea',
#  'Western Sahara',
#  'Guinea-Bissau',
#  'Sierra Leone',
#  'Diamond Princess',
#  'Zimbabwe',
#  'Cabo Verde',
#  'Chad',
#  'Haiti',
#  'Gambia',
#  'Uganda',
#  'Niger',
#  'Mali',
#  'MS Zaandam',
#  'Belize',
#  'Zambia',
#  'Burma',
#  'El Salvador',
#  'Malawi',
#  'Timor-Leste',
#  'West Bank and Gaza',
#  'Mozambique',
#  'Syria',
#  'Kyrgyzstan',
#  'Saint Kitts and Nevis',
#  'Fiji',
#  'Angola',
#  'Botswana',
#  'Eritrea',
#  'Grenada',
#  'Nicaragua',
#  'Yemen',
#  'Dominica',
#  'Bahamas',
#  'Djibouti',
#  'Burundi',
#  'Mauritius',
#  'Sao Tome and Principe',
#  'Laos',
#  'Madagascar',
#  'South Sudan',
#  'Libya_daily',
#  'Papua New Guinea_daily',
#  'Western Sahara_daily',
#  'Guinea-Bissau_daily',
#  'Sierra Leone_daily',
#  'Diamond Princess_daily',
#  'Zimbabwe_daily',
#  'Cabo Verde_daily',
#  'Chad_daily',
#  'Haiti_daily',
#  'Gambia_daily',
#  'Uganda_daily',
#  'Niger_daily',
#  'Mali_daily',
#  'MS Zaandam_daily',
#  'Belize_daily',
#  'Zambia_daily',
#  'Burma_daily',
#  'El Salvador_daily',
#  'Malawi_daily',
#  'Timor-Leste_daily',
#  'West Bank and Gaza_daily',
#  'Mozambique_daily',
#  'Syria_daily',
#  'Kyrgyzstan_daily',
#  'Saint Kitts and Nevis_daily',
#  'Fiji_daily',
#  'Angola_daily',
#  'Botswana_daily',
#  'Eritrea_daily',
#  'Grenada_daily',
#  'Nicaragua_daily',
#  'Yemen_daily',
#  'Dominica_daily',
#  'Bahamas_daily',
#  'Djibouti_daily',
#  'Burundi_daily',
#  'Mauritius_daily',
#  'Sao Tome and Principe_daily',
#  'Laos_daily',
#  'Madagascar_daily',
#  'South Sudan_daily']

# %%
def pop_perc(df):
    for col in tqdm(df.columns):
        if not col.endswith('_daysplus') and col not in ['Date', 'dayofyear'] + missing:
            #print(col)
            #print(int(population_df[population_df.Territory == col.split('_')[0]]['Population']))
            #display(df[col])#/(int(population_df[population_df.Territory == col.split('_')[0]]['Population'])))
            df[col] = df[col]/(int(population_df[population_df.Territory == col.split('_')[0]]['Population']))
    return df

# %%
import copy
csse_perc = copy.deepcopy(csse)

# %%
def dayplus_perc(row, df, country):
    first_day = df[df[country] > 0.00001].dayofyear.min()
    if np.isnan(first_day) or row.dayofyear <= first_day:
        return 0
    else:
        return row.dayofyear - first_day

# %%
for key, value in csse_perc.items():
    csse_perc[key] = pop_perc(value)
    for country in tqdm(list(territories) + ['non-China', 'world', 'non-China-Italy']):
        #df[str(country) + '_daily'] = df.apply(lambda x : delta(x, df, country, firstday = df.dayofyear.min()), axis = 1)
        csse_perc[key][str(country) + '_daysplus'] = csse_perc[key].apply(lambda x : dayplus_perc(x, csse_perc[key], country), axis = 1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 568/568 [00:00<00:00, 2385.24it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:10<00:00, 17.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 568/568 [00:00<00:00, 2374.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:09<00:00, 19.30it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 568/568 [00:00<00:00, 2394.55it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:10<00:00, 18.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 568/568 [00:00<00:00, 2370.52it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:10<00:00, 17.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 568/568 [00:00<00:00, 2998.86it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [00:10<00:00, 17.69it/s]

# %%
#for key, value in csse_perc.items():
#    display(csse_perc[key].head())

# %%
#csse['confirmed'][territories].iloc[len(csse['confirmed'])-1].sort_values(ascending=False)

# %%
#csse['absolute']['Spain'][csse['absolute']['Spain'] >=
#                               csse['absolute']['Argentina'].iloc[len(csse['absolute']['Argentina'])-8]]

# %%
import matplotlib.ticker as mtick

plt.figure(figsize=(15, 10))
sns.set_context("talk")
#sns.lineplot(data=csse['confirmed'][['non-China-Italy_daily']], markers=True, dashes=False)
#sns.lineplot(data=csse['recovered'][['non-China-Italy_daily']], markers=False, dashes=True)
top_10 = list(csse['confirmed'][territories].iloc[len(csse['confirmed'])-1].sort_values(ascending=False).head(11).index)
top_10.remove('China')
#top_10 = ['Argentina', 'Italy',  'Spain', 'Brazil', 'China - Hubei', 'US', 'United Kingdom']#, 'Iran', 'Korea, South', 'United Kingdom']#'US',
for c in top_10:
    #print(c)
    #display(csse_perc['absolute'][csse['confirmed'][c]>100][c+'_daysplus'])
    ax = sns.lineplot(x=csse_perc['absolute'][csse_perc['confirmed'][c]>0.00001][c+'_daysplus'], 
                 y=csse_perc['absolute'][csse_perc['confirmed'][c]>0.00001][c], markers=True, dashes=True, label=c)
ax.set(xlabel='Days since 0.01% infected', ylabel='Percentage of infected people', title='Top 10 infected territories')
ax.set(yscale="log")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

plt.show()
plt.figure(figsize=(15, 10))
for c in top_10:
    ax = sns.lineplot(x=csse_perc['absolute'][(csse_perc['absolute'][c]>0.00001) & (csse_perc['confirmed'][c+'_daysplus']<30)][c+'_daysplus'], 
                 y=csse_perc['absolute'][(csse_perc['absolute'][c]>0.00001) & (csse_perc['confirmed'][c+'_daysplus']<30)][c], markers=True, dashes=True, label=c)
ax.set(xlabel='Days since 0.01% infected', ylabel='Percentage of infected people', title='Top 10 infected territories')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.set(yscale="log")
# Out:
# c:\program files\python36\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None]

# %%
#plt.figure(figsize=(6, 6))
cols = [x for x in csse['ma'].columns if x not in ['Date', 'dayofyear'] and not x.endswith('_daily') and not x.endswith('_daysplus')]
nr_rows = int(len(cols) / 3) + 2 
nr_cols = 3
print(nr_rows)
print(nr_cols)
fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*3.5,nr_rows*3))
#'Italy_daily', 'China_daily',
for ix, col in tqdm(enumerate(cols)):
    r = ix // 3
    c = ix % 3
    if col not in ['Date', 'dayofyear'] and not col.endswith('_daily') and not col.endswith('_daysplus'):
        sns.lineplot(data=csse['confirmed'][[col]], markers=True, dashes=False, ax = axs[r][c])
        #plt.show()
plt.tight_layout()    
plt.show()  
#sns.lineplot(data=csse['confirmed'][['non-China-Italy_daily']], markers=True, dashes=False)
#sns.lineplot(data=csse['recovered'][['non-China-Italy_daily']], markers=False, dashes=True)

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = ARIMA(csse['confirmed'][['world_daily']], order=(20,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# c:\program files\python36\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# c:\program files\python36\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# c:\program files\python36\lib\site-packages\scipy\signal\signaltools.py:1333: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# c:\program files\python36\lib\site-packages\scipy\signal\signaltools.py:1336: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# c:\program files\python36\lib\site-packages\scipy\signal\signaltools.py:1342: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]
# c:\program files\python36\lib\site-packages\statsmodels\base\model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# c:\program files\python36\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py:1663: RuntimeWarning: invalid value encountered in double_scalars
#   ('S.D. of innovations', ["%#5.3f" % self.sigma2 ** .5]),
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:          D.world_daily   No. Observations:                   82
# Model:                ARIMA(20, 1, 0)   Log Likelihood                -837.107
# Method:                       css-mle   S.D. of innovations                nan
# Date:                Tue, 14 Apr 2020   AIC                           1718.213
# Time:                        15:48:11   BIC                           1771.161
# Sample:                    01-23-2020   HQIC                          1739.471
#                          - 04-13-2020
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  861.4467    439.403      1.960      0.050       0.233    1722.660
# ar.L1.D.world_daily     -0.5233      0.000  -3450.218      0.000      -0.524      -0.523
# ar.L2.D.world_daily     -0.3519      0.002   -217.908      0.000      -0.355      -0.349
# ar.L3.D.world_daily     -0.1393        nan        nan        nan         nan         nan
# ar.L4.D.world_daily      0.0425      0.000    101.348      0.000       0.042       0.043
# ar.L5.D.world_daily      0.0522      0.001     96.856      0.000       0.051       0.053
# ar.L6.D.world_daily      0.3425        nan        nan        nan         nan         nan
# ar.L7.D.world_daily      0.4725        nan        nan        nan         nan         nan
# ar.L8.D.world_daily      0.5313        nan        nan        nan         nan         nan
# ar.L9.D.world_daily      0.4456      0.001    377.991      0.000       0.443       0.448
# ar.L10.D.world_daily     0.1987      0.001    217.269      0.000       0.197       0.200
# ar.L11.D.world_daily    -0.0758      0.001    -64.564      0.000      -0.078      -0.073
# ar.L12.D.world_daily    -0.0105      0.001    -13.894      0.000      -0.012      -0.009
# ar.L13.D.world_daily    -0.0874      0.004    -21.890      0.000      -0.095      -0.080
# ar.L14.D.world_daily    -0.0756      0.002    -43.663      0.000      -0.079      -0.072
# ar.L15.D.world_daily    -0.1427        nan        nan        nan         nan         nan
# ar.L16.D.world_daily    -0.1802      0.001   -131.444      0.000      -0.183      -0.178
# ar.L17.D.world_daily    -0.3691        nan        nan        nan         nan         nan
# ar.L18.D.world_daily    -0.2789      0.000  -1295.955      0.000      -0.279      -0.278
# ar.L19.D.world_daily    -0.2964      0.001   -565.023      0.000      -0.297      -0.295
# ar.L20.D.world_daily    -0.1265      0.002    -83.000      0.000      -0.129      -0.123
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             0.9954           -0.1206j            1.0027           -0.0192
# AR.2             0.9954           +0.1206j            1.0027            0.0192
# AR.3             0.9057           -0.6180j            1.0964           -0.0953
# AR.4             0.9057           +0.6180j            1.0964            0.0953
# AR.5             0.6209           -0.7839j            1.0000           -0.1434
# AR.6             0.6209           +0.7839j            1.0000            0.1434
# AR.7             0.3642           -1.0700j            1.1302           -0.1978
# AR.8             0.3642           +1.0700j            1.1302            0.1978
# AR.9             0.0367           -1.0945j            1.0951           -0.2447
# AR.10            0.0367           +1.0945j            1.0951            0.2447
# AR.11           -0.2672           -1.1221j            1.1535           -0.2872
# AR.12           -0.2672           +1.1221j            1.1535            0.2872
# AR.13           -0.5116           -0.9242j            1.0563           -0.3305
# AR.14           -0.5116           +0.9242j            1.0563            0.3305
# AR.15           -0.8498           -0.7229j            1.1157           -0.3878
# AR.16           -0.8498           +0.7229j            1.1157            0.3878
# AR.17           -1.0354           -0.0000j            1.0354           -0.5000
# AR.18           -1.0143           -0.4068j            1.0929           -0.4393
# AR.19           -1.0143           +0.4068j            1.0929            0.4393
# AR.20           -1.8686           -0.0000j            1.8686           -0.5000
# ------------------------------------------------------------------------------
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py:1490: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(-inv(hess)))
# c:\program files\python36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# c:\program files\python36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# c:\program files\python36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                   0
# count     82.000000
# mean    -284.239338
# std     5658.656734
# min   -12580.226510
# 25%    -2962.418748
# 50%     -758.377356
# 75%     1481.284704
# max    27345.483313

# %%
fig, ax = plt.subplots(figsize=(15, 10))
fig = model_fit.plot_predict(1, 125, dynamic=False, ax=ax,
                        plot_insample=True)
#model_fit.plot_predict(20,105)
# Out:
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py:1866: RuntimeWarning: invalid value encountered in sqrt
#   fcerr = np.sqrt(np.cumsum(cumsum_n(ma_rep, self.k_diff) ** 2) * sigma2)

# %%
csse['ma']['Argentina']
# Out:
# Date
# 2020-01-22       0.0
# 2020-01-23       0.0
# 2020-01-24       0.0
# 2020-01-25       0.0
# 2020-01-26       0.0
#                ...
# 2020-04-03     900.5
# 2020-04-04    1044.5
# 2020-04-05    1128.0
# 2020-04-06    1154.0
# 2020-04-07    1207.5
# Name: Argentina, Length: 77, dtype: float64

# %%
X = csse['confirmed']['Argentina'].values
size = int(len(X) * 0.1)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot

pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-3a8dfe1cc4e8> in <module>()
#       6 for t in range(len(test)):
#       7     model = ARIMA(history, order=(5,1,0))
# ----> 8     model_fit = model.fit(disp=0)
#       9     output = model_fit.forecast()
#      10     yhat = output[0]
#
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1198                                         method, transparams, solver,
#    1199                                         maxiter, full_output, disp,
# -> 1200                                         callback, start_ar_lags, **kwargs)
#    1201         normalized_cov_params = None  # TODO: fix this?
#    1202         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     960
#     961         # check again now that we know the trend
# --> 962         _check_estimable(len(endog), k_ar + k_ma + k_exog + k_trend)
#     963
#     964         self.k_trend = k_trend
#
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py in _check_estimable(nobs, n_params)
#     430 def _check_estimable(nobs, n_params):
#     431     if nobs <= n_params:
# --> 432         raise ValueError("Insufficient degrees of freedom to estimate")
#     433
#     434
#
# ValueError: Insufficient degrees of freedom to estimate

# %%
"""
X = csse['absolute']['China'].values

predictions = list()
size = int(len(X) * 0.5)
train, test = X[0:size], X[size:len(X)]
predictions = list()
history = [x for x in train]
for t in range(len(X)*2):
    model = ARIMA(history, order=(2,1,2))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    if t < len(test):
        obs = test[t]
    else:
        obs = yhat
    history.append(obs)
    #print(predictions)
    #print(history)
    print('predicted=%f, expected=%f' % (yhat, obs))
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
"""
# Out:
# "\nX = csse['absolute']['China'].values\n\npredictions = list()\nsize = int(len(X) * 0.5)\ntrain, test = X[0:size], X[size:len(X)]\npredictions = list()\nhistory = [x for x in train]\nfor t in range(len(X)*2):\n    model = ARIMA(history, order=(2,1,2))\n    model_fit = model.fit(disp=0)\n    output = model_fit.forecast()\n    yhat = output[0]\n    predictions.append(yhat)\n    if t < len(test):\n        obs = test[t]\n    else:\n        obs = yhat\n    history.append(obs)\n    #print(predictions)\n    #print(history)\n    print('predicted=%f, expected=%f' % (yhat, obs))\npyplot.plot(test)\npyplot.plot(predictions, color='red')\npyplot.show()\n"

# %%
model= SARIMAX(csse['absolute']['non-China'].iloc[20:50], 
 exog=np.array(csse['absolute']['China'].iloc[0:30]).reshape(30, 1),
 order=(0,1,1),
 enforce_invertibility=False, enforce_stationarity=False)
# Out:
# c:\users\lbasla001\python36\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# c:\users\lbasla001\python36\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
results= model.fit()

# %%
predictions= results.forecast(50,exog=np.array(csse['absolute']['China']).reshape(50, 1))

# %%
pd.concat([predictions,csse['absolute']['non-China']]).plot()
#predictions.plot()
